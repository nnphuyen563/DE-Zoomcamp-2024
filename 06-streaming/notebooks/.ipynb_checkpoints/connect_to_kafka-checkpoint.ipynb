# %%
import json
import time 

from kafka import KafkaProducer

def json_serializer(data):
    return json.dumps(data).encode('utf-8')

server = 'localhost:9092'

producer = KafkaProducer(
    bootstrap_servers=[server],
    value_serializer=json_serializer
)

producer.bootstrap_connected()
# Out:
# ---------------------------------------------------------------------------
# NoBrokersAvailable                        Traceback (most recent call last)
# Cell In[1], line 11
#       7     return json.dumps(data).encode('utf-8')
#       9 server = 'localhost:9092'
# ---> 11 producer = KafkaProducer(
#      12     bootstrap_servers=[server],
#      13     value_serializer=json_serializer
#      14 )
#      16 producer.bootstrap_connected()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\kafka\producer\kafka.py:381, in KafkaProducer.__init__(self, **configs)
#     378 reporters = [reporter() for reporter in self.config['metric_reporters']]
#     379 self._metrics = Metrics(metric_config, reporters)
# --> 381 client = KafkaClient(metrics=self._metrics, metric_group_prefix='producer',
#     382                      wakeup_timeout_ms=self.config['max_block_ms'],
#     383                      **self.config)
#     385 # Get auto-discovered version from client if necessary
#     386 if self.config['api_version'] is None:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\kafka\client_async.py:244, in KafkaClient.__init__(self, **configs)
#     242 if self.config['api_version'] is None:
#     243     check_timeout = self.config['api_version_auto_timeout_ms'] / 1000
# --> 244     self.config['api_version'] = self.check_version(timeout=check_timeout)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\kafka\client_async.py:927, in KafkaClient.check_version(self, node_id, timeout, strict)
#     924 # Timeout
#     925 else:
#     926     self._lock.release()
# --> 927     raise Errors.NoBrokersAvailable()
#
# NoBrokersAvailable: NoBrokersAvailable

# %%
t0 = time.time()

topic_name = 'test-topic'

for i in range(10):
    message = {'number': i}
    producer.send(topic_name, value=message)
    print(f"Sent: {message}")
    time.sleep(0.05)

producer.flush()

t1 = time.time()
print(f'took {(t1 - t0):.2f} seconds')
# Out:
# Sent: {'number': 0}
# Sent: {'number': 1}
# Sent: {'number': 2}
# Sent: {'number': 3}
# Sent: {'number': 4}
# Sent: {'number': 5}
# Sent: {'number': 6}
# Sent: {'number': 7}
# Sent: {'number': 8}
# Sent: {'number': 9}
# took 0.56 seconds

# %%
# !wget https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2019-10.csv.gz

# %%
import pandas as pd

# %%
data = pd.read_csv('green_tripdata_2019-10.csv.gz', compression='gzip')
data
# Out:
# C:\Users\nnphu\AppData\Local\Temp\ipykernel_24164\1544737345.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('green_tripdata_2019-10.csv.gz', compression='gzip')
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0            2.0  2019-10-01 00:26:02   2019-10-01 00:39:58
# 1            1.0  2019-10-01 00:18:11   2019-10-01 00:22:38
# 2            1.0  2019-10-01 00:09:31   2019-10-01 00:24:47
# 3            1.0  2019-10-01 00:37:40   2019-10-01 00:41:49
# 4            2.0  2019-10-01 00:08:13   2019-10-01 00:17:56
# ...          ...                  ...                   ...
# 476381       NaN  2019-10-31 23:30:00   2019-11-01 00:00:00
# 476382       NaN  2019-10-31 23:03:00   2019-10-31 23:24:00
# 476383       NaN  2019-10-31 23:02:00   2019-10-31 23:23:00
# 476384       NaN  2019-10-31 23:42:00   2019-10-31 23:56:00
# 476385       NaN  2019-10-31 23:23:00   2019-10-31 23:56:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N         1.0           112           196
# 1                       N         1.0            43           263
# 2                       N         1.0           255           228
# 3                       N         1.0           181           181
# 4                       N         1.0            97           188
# ...                   ...         ...           ...           ...
# 476381                NaN         NaN            65           102
# 476382                NaN         NaN           129           136
# 476383                NaN         NaN            61           222
# 476384                NaN         NaN            76            39
# 476385                NaN         NaN            56           215
#
#         passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 0                   1.0           5.88        18.00   0.50      0.5
# 1                   1.0           0.80         5.00   3.25      0.5
# 2                   2.0           7.50        21.50   0.50      0.5
# 3                   1.0           0.90         5.50   0.50      0.5
# 4                   1.0           2.52        10.00   0.50      0.5
# ...                 ...            ...          ...    ...      ...
# 476381              NaN           7.04        29.57   2.75      0.5
# 476382              NaN           0.00        39.83   2.75      0.5
# 476383              NaN           3.90        23.11   2.75      0.5
# 476384              NaN           3.08        15.23   2.75      0.5
# 476385              NaN           6.84        36.12   2.75      0.5
#
#         tip_amount  tolls_amount  ehail_fee  improvement_surcharge  \
# 0             0.00          0.00        NaN                    0.3
# 1             0.00          0.00        NaN                    0.3
# 2             0.00          0.00        NaN                    0.3
# 3             0.00          0.00        NaN                    0.3
# 4             2.26          0.00        NaN                    0.3
# ...            ...           ...        ...                    ...
# 476381        0.00          0.00        NaN                    0.0
# 476382        0.00          6.12        NaN                    0.0
# 476383        0.00          0.00        NaN                    0.0
# 476384        0.00          0.00        NaN                    0.0
# 476385        0.00          0.00        NaN                    0.3
#
#         total_amount  payment_type  trip_type  congestion_surcharge
# 0              19.30           2.0        1.0                   0.0
# 1               9.05           2.0        1.0                   0.0
# 2              22.80           2.0        1.0                   0.0
# 3               6.80           2.0        1.0                   0.0
# 4              13.56           1.0        1.0                   0.0
# ...              ...           ...        ...                   ...
# 476381         32.82           NaN        NaN                   NaN
# 476382         49.20           NaN        NaN                   NaN
# 476383         26.36           NaN        NaN                   NaN
# 476384         18.48           NaN        NaN                   NaN
# 476385         39.67           NaN        NaN                   NaN
#
# [476386 rows x 20 columns]

# %%
df_green = data[['lpep_pickup_datetime',
'lpep_dropoff_datetime',
'PULocationID',
'DOLocationID',
'passenger_count',
'trip_distance',
'tip_amount']]
df_green.head()
# Out:
#   lpep_pickup_datetime lpep_dropoff_datetime  PULocationID  DOLocationID  \
# 0  2019-10-01 00:26:02   2019-10-01 00:39:58           112           196
# 1  2019-10-01 00:18:11   2019-10-01 00:22:38            43           263
# 2  2019-10-01 00:09:31   2019-10-01 00:24:47           255           228
# 3  2019-10-01 00:37:40   2019-10-01 00:41:49           181           181
# 4  2019-10-01 00:08:13   2019-10-01 00:17:56            97           188
#
#    passenger_count  trip_distance  tip_amount
# 0              1.0           5.88        0.00
# 1              1.0           0.80        0.00
# 2              2.0           7.50        0.00
# 3              1.0           0.90        0.00
# 4              1.0           2.52        2.26

# %%
t0 = time.time()

topic_name = 'green-trips'

# %%
for row in df_green.itertuples(index=False):
    row_dict = {col: getattr(row, col) for col in row._fields}
    producer.send(topic_name, value=row_dict)

    # TODO implement sending the data 
producer.flush()
t1 = time.time()
print(f'took {(t1 - t0):.2f} seconds')
# Out:
# took 77.56 seconds

# %%
import findspark
findspark.init()

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark import SparkContext, SparkConf


pyspark_version = pyspark.__version__
kafka_jar_package = f'org.apache.spark:spark-sql-kafka-0-10_2.12:3.2.3'


spark = SparkSession \
    .builder \
    .master("local[*]") \
    .appName("GreenTripsConsumer") \
    .config("spark.jars.packages", kafka_jar_package) \
    .getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 14
#       6 pyspark_version = pyspark.__version__
#       7 kafka_jar_packag = f'org.apache.spark:spark-sql-kafka-0-10_2.12:3.2.3'
#      10 spark = SparkSession \
#      11     .builder \
#      12     .master("local[*]") \
#      13     .appName("GreenTripsConsumer") \
# ---> 14     .config("spark.jars.packages", kafka_jar_package) \
#      15     .getOrCreate()
#
# NameError: name 'kafka_jar_package' is not defined

# %%
green_stream = spark \
    .readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "localhost:9092") \
    .option("subscribe", "green-trips") \
    .option("startingOffsets", "earliest") \
    .load()
